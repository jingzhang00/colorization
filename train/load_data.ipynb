# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
path="/root/diffusers/examples/controlnet/conditioning_image_2.png"
img = Image.open(path)
imgSize = img.size  #大小/尺寸
w = img.width       #图片的宽
h = img.height      #图片的高
f = img.format      #图像格式
 
print(imgSize)
# Out:
# (512, 512)

# %%
data1, data2 = data["arr_0"], data["arr_1"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data1, data2 = data["arr_0"], data["arr_1"]
#
# NameError: name 'data' is not defined

# %%
data1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data1.shape
#
# NameError: name 'data1' is not defined

# %%
plt.imshow(data1[0])

# %%
print(data.keys())
# Out:
# KeysView(<numpy.lib.npyio.NpzFile object at 0x7f24c5a5ba60>)
